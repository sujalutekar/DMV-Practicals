# %%
import pandas as pd

df = pd.read_csv('/content/Housing.csv')

df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# Filter and subset the data

filtered_df = df[(df['furnishingstatus'] == 'furnished') & (df['mainroad'] == 'yes') & (df['bedrooms'] >= 2)]

filtered_df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 8     9870000  8100         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 493   2800000  3960         3          1        1      yes        no       no
# 509   2590000  3600         2          2        2      yes        no      yes
# 512   2520000  3000         2          1        2      yes        no       no
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
#
# ...

# %%
# if you want to change the column name

filtered_df.rename(columns = {'bedrooms': 'bedrooms and hall'}, inplace = True)

filtered_df
# Out:
# <ipython-input-15-fba2df906226>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.rename(columns = {'bedrooms': 'bedrooms and hall'}, inplace = True)
#         price  area  bedrooms and hall  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420                  4          2        3      yes        no
# 1    12250000  8960                  4          4        4      yes        no
# 3    12215000  7500                  4          2        2      yes        no
# 4    11410000  7420                  4          1        2      yes       yes
# 8     9870000  8100                  4          1        2      yes       yes
# ..        ...   ...                ...        ...      ...      ...       ...
# 493   2800000  3960                  3          1        1      yes        no
# ...

# %%
# Clean column names

filtered_df.columns = filtered_df.columns.str.strip().str.replace(' ', '_').str.replace(r'[^a-zA-Z0-9_]', '')

filtered_df
# Out:
#         price  area  bedrooms_and_hall  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420                  4          2        3      yes        no
# 1    12250000  8960                  4          4        4      yes        no
# 3    12215000  7500                  4          2        2      yes        no
# 4    11410000  7420                  4          1        2      yes       yes
# 8     9870000  8100                  4          1        2      yes       yes
# ..        ...   ...                ...        ...      ...      ...       ...
# 493   2800000  3960                  3          1        1      yes        no
# 509   2590000  3600                  2          2        2      yes        no
# 512   2520000  3000                  2          1        2      yes        no
# 522   2380000  2475                  3          1        2      yes        no
# 523   2380000  2787                  4          2        2      yes        no
#
# ...

# %%
#  One-hot encoding
# Example: If a "Location" column has values "Downtown," "Suburb," and "Rural," one-hot encoding will create three new columns: "Location_Downtown," "Location_Suburb," and "Location_Rural."


df_encoded = pd.get_dummies(df, columns=['furnishingstatus', 'basement'], drop_first = True)

df_encoded
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420         4          2        3      yes        no
# 1    12250000  8960         4          4        4      yes        no
# 2    12250000  9960         3          2        2      yes        no
# 3    12215000  7500         4          2        2      yes        no
# 4    11410000  7420         4          1        2      yes       yes
# ..        ...   ...       ...        ...      ...      ...       ...
# 540   1820000  3000         2          1        1      yes        no
# 541   1767150  2400         3          1        1       no        no
# 542   1750000  3620         2          1        1      yes        no
# 543   1750000  2910         3          1        1       no        no
# 544   1750000  3850         3          1        2      yes        no
#
#     hotwaterheating airconditioning  parking prefarea  \
# 0                no             yes        2      yes
# ...

# %%
# Aggregate Data

avg_price_by_area = df.groupby('area')['price'].mean()

avg_price_by_area
# Out:
# area
# 1650      3150000.0
# 1700      1890000.0
# 1836      2275000.0
# 1905      4340000.0
# 1950      2835000.0
#             ...
# 12900     4900000.0
# 12944     3500000.0
# 13200     8365000.0
# 15600     5943000.0
# 16200    10150000.0
# Name: price, Length: 284, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 8))
sns.boxplot(data = df['price'])
plt.show()

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# The factor of 1.5 is a commonly used threshold in the Interquartile Range (IQR) method to identify outliers.

df = df[(df['price'] >= lower_bound) & (df['price'] <= upper_bound)]

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(data = df[['price']])
plt.show()
